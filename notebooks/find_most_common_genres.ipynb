# %%
import os
import pandas as pd

# %% [markdown]
# ## Load the data

# %%
data=pd.read_csv('/home/stefan/Desktop/git_ncmml/ncmml_project/data/tracks_5k_w_genres.csv')
##data.info()

# %%
genres_list = data.genres.unique().tolist()
#genres_list

# %% [markdown]
# ## Prepare the genre list to perform map reduce

# %%
import re

modified_list = []
regex = re.compile('[^a-zA-Z, ]')
def fix_the_list(l):
    for i in range(len(l)):
            l[i]=l[i].strip()
            word=regex.sub("", l[i])
            word = word.split(',')
            for i in range(len(word)):
                word[i] = word[i].lstrip()
                if word[i] != "":
                    modified_list.append(word[i])
                    
fix_the_list(genres_list)

# %%
from contextlib import redirect_stdout

with open('out.txt', 'w') as f:
    with redirect_stdout(f):
        for el in modified_list:
            print ('%s\t%s' % (el, 1))

# %% [markdown]
# ## Run the reducer through the terminal and check the results

# %%
cat out.txt |sort -k1,1| python reduce.py  > output_reducer.txt

# %% [markdown]
# ## Check the contents

# %%
f = open('output_reducer.txt', 'r')
file_contents = f.read()
print (file_contents)
f.close()
# Out:
# acoustic blues	14
# adult standards	33
# africanamerican classical	2
# american folk revival	1
# american modern classical	4
# american orchestra	3
# american romanticism	1
# appalachian folk	7
# arab folk	1
# banjo	2
# baroque	5
# barrelhouse piano	4
# bebop	5
# belly dance	1
# big band	52
# bluegrass	1
# blues	21
# blues rock	1
# boogiewoogie	11
# brass ensemble	1
# brill building pop	2
# british dance band	1
# british modern classical	4
# british orchestra	1
# broadway	2
# cabaret	2
# cajun	2
# canzone napoletana	3
# chicago blues	4
# childrens choir	2
# classic arab pop	1
# classic soul	1
# classic soundtrack	1
# classical	59
# classical bass	1
# classical era	9
# classical organ	1
# classical performance	38
# classical piano	21
# classical tenor	2
# concert band	1
# cool jazz	7
# cornetas y tambores	1
# country blues	15
# country gospel	1
# cowboy western	1
# czech classical	1
# deep delta blues	5
# deep free jazz	1
# delta blues	7
# dixieland	17
# early modern classical	17
# early music	9
# early romantic era	9
# easy listening	15
# electric blues	3
# english baroque	1
# folk	2
# french folk	1
# french opera	1
# french romanticism	2
# galante era	1
# german baroque	4
# german choir	2
# german opera	7
# german orchestra	17
# german romanticism	19
# gospel	1
# gospel blues	2
# hardcore punk	1
# harlem renaissance	19
# harmonica blues	2
# historic classical performance	8
# historic orchestral performance	8
# impressionism	2
# italian baritone	1
# italian baroque	1
# italian opera	11
# italian romanticism	12
# italian tenor	2
# jazz	15
# jazz blues	7
# jazz clarinet	8
# jazz guitar	5
# jazz piano	12
# jazz quartet	1
# jazz saxophone	2
# jazz trombone	8
# jazz trumpet	16
# jug band	7
# jump blues	4
# late romantic era	21
# library music	1
# light music	2
# louisiana blues	4
# lounge	26
# marching band	1
# memphis blues	4
# memphis soul	1
# movie tunes	1
# musica tradicional cubana	1
# neoclassicism	2
# new orleans blues	4
# new orleans jazz	10
# oklahoma country	1
# oldtime	3
# operetta	1
# orchestra	21
# orchestral performance	9
# orquesta tipica	1
# piano blues	5
# piedmont blues	8
# polish classical	3
# polish classical piano	1
# portland hip hop	1
# postromantic era	18
# prewar blues	3
# psychedelic rock	1
# ragtime	3
# reading	2
# rhythm and blues	3
# rockabilly	1
# rockandroll	2
# russian choir	1
# russian classical piano	20
# russian folk	1
# russian modern classical	2
# russian romanticism	6
# show tunes	1
# son cubano	1
# son cubano clasico	1
# soul	9
# southern soul	2
# space age pop	2
# spirituals	1
# spytrack	1
# stride	37
# string band	1
# swing	52
# tango	4
# tango cancion	1
# tape club	1
# texas blues	2
# tin pan alley	12
# torch song	9
# traditional blues	28
# traditional country	2
# traditional folk	9
# turkish classical	1
# turkish jazz	1
# ukrainian classical	3
# victorian britain	1
# vintage chanson	3
# vintage classical singing	2
# vintage country folk	5
# vintage hollywood	2
# vintage jazz	25
# vintage oldtime	1
# vintage schlager	2
# vintage swing	3
# vintage tango	4
# vintage western	1
# vocal harmony group	3
# vocal jazz	24
# western swing	2
# yodeling	2
# zydeco	1

# %%
top_genres = file_contents.split('\n')
top_glist = []

for line in top_genres:
    line.strip(" ")
    top_glist.append(line.split("\t"))
    
#columns_df = ['Genre', 'Count']
genres_df = pd.DataFrame(data = top_glist, columns =['Genre', 'Count'] )

# %% [markdown]
# ## Display top 15 genres by count

# %%
genres_df['Count'] = pd.to_numeric(genres_df['Count'])
genres_df.nlargest(15, 'Count')
# Out:
#                        Genre  Count
# 33                 classical   59.0
# 14                  big band   52.0
# 138                    swing   52.0
# 37     classical performance   38.0
# 136                   stride   37.0
# 1            adult standards   33.0
# 145        traditional blues   28.0
# 95                    lounge   26.0
# 156             vintage jazz   25.0
# 163               vocal jazz   24.0
# 16                     blues   21.0
# 38           classical piano   21.0
# 91         late romantic era   21.0
# 107                orchestra   21.0
# 124  russian classical piano   20.0
