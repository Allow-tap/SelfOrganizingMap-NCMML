# %%
import os
import pandas as pd

# %% [markdown]
# ## Load the data

# %%
data=pd.read_csv('/home/stefan/Desktop/git_ncmml/ncmml_project/data/tracks_5k_w_genres.csv')
##data.info()

# %%
#genres_list = data.genres.unique().tolist()
genres_list = data.genres.tolist()
#genres_list

# %% [markdown]
# ## Prepare the genre list to perform map reduce

# %%
import re

modified_list = []
regex = re.compile('[^a-zA-Z, ]')
def fix_the_list(l):
    for i in range(len(l)):
            l[i]=l[i].strip()
            word=regex.sub("", l[i])
            word = word.split(',')
            for i in range(len(word)):
                word[i] = word[i].lstrip()
                if word[i] != "":
                    modified_list.append(word[i])
                    
fix_the_list(genres_list)

# %%
from contextlib import redirect_stdout

with open('out.txt', 'w') as f:
    with redirect_stdout(f):
        for el in modified_list:
            print ('%s\t%s' % (el, 1))

# %% [markdown]
# ## Run the reducer through the terminal and check the results

# %%
cat out.txt |sort -k1,1| python reduce.py  > output_reducer.txt

# %% [markdown]
# ## Check the contents

# %%
f = open('output_reducer.txt', 'r')
file_contents = f.read()
print (file_contents)
f.close()
# Out:
# acoustic blues	41
# adult standards	289
# africanamerican classical	4
# american folk revival	1
# american modern classical	14
# american orchestra	10
# american romanticism	1
# appalachian folk	65
# arab folk	18
# banjo	2
# baroque	10
# barrelhouse piano	43
# bebop	11
# belly dance	18
# big band	230
# bluegrass	44
# blues	118
# blues rock	1
# boogiewoogie	87
# brass ensemble	2
# brill building pop	2
# british dance band	4
# british modern classical	16
# british orchestra	1
# broadway	5
# cabaret	28
# cajun	8
# canzone napoletana	3
# chicago blues	4
# childrens choir	4
# classic arab pop	18
# classic soul	1
# classic soundtrack	1
# classical	308
# classical bass	1
# classical era	26
# classical organ	1
# classical performance	266
# classical piano	236
# classical tenor	22
# concert band	1
# cool jazz	12
# cornetas y tambores	13
# country blues	48
# country gospel	1
# cowboy western	6
# czech classical	1
# deep delta blues	8
# deep free jazz	1
# delta blues	9
# dixieland	276
# early modern classical	65
# early music	18
# early romantic era	175
# easy listening	63
# electric blues	3
# english baroque	4
# folk	45
# french folk	1
# french opera	1
# french romanticism	2
# galante era	3
# german baroque	6
# german choir	4
# german opera	10
# german orchestra	30
# german romanticism	69
# gospel	1
# gospel blues	17
# hardcore punk	1
# harlem renaissance	297
# harmonica blues	4
# historic classical performance	8
# historic orchestral performance	40
# impressionism	23
# italian baritone	1
# italian baroque	1
# italian opera	18
# italian romanticism	19
# italian tenor	38
# jazz	145
# jazz blues	41
# jazz clarinet	16
# jazz guitar	9
# jazz piano	160
# jazz quartet	1
# jazz saxophone	2
# jazz trombone	41
# jazz trumpet	119
# jug band	30
# jump blues	4
# late romantic era	62
# library music	9
# light music	6
# louisiana blues	29
# lounge	83
# marching band	1
# memphis blues	15
# memphis soul	1
# movie tunes	1
# musica tradicional cubana	2
# neoclassicism	5
# new orleans blues	29
# new orleans jazz	342
# oklahoma country	6
# oldtime	46
# operetta	5
# orchestra	41
# orchestral performance	17
# orquesta tipica	125
# piano blues	43
# piedmont blues	13
# polish classical	128
# polish classical piano	27
# portland hip hop	1
# postromantic era	30
# prewar blues	19
# psychedelic rock	31
# ragtime	28
# reading	21
# rhythm and blues	3
# rockabilly	1
# rockandroll	2
# russian choir	1
# russian classical piano	209
# russian folk	1
# russian modern classical	6
# russian romanticism	32
# show tunes	4
# son cubano	2
# son cubano clasico	2
# soul	86
# southern soul	2
# space age pop	4
# spirituals	1
# spytrack	9
# stride	282
# string band	1
# swing	389
# tango	1066
# tango cancion	1
# tape club	1
# texas blues	17
# tin pan alley	199
# torch song	27
# traditional blues	134
# traditional country	50
# traditional folk	67
# turkish classical	1
# turkish jazz	1
# ukrainian classical	7
# victorian britain	1
# vintage chanson	107
# vintage classical singing	18
# vintage country folk	22
# vintage hollywood	30
# vintage jazz	173
# vintage oldtime	1
# vintage schlager	8
# vintage swing	3
# vintage tango	1066
# vintage western	1
# vocal harmony group	3
# vocal jazz	260
# western swing	2
# yodeling	50
# zydeco	4

# %%
top_genres = file_contents.split('\n')
top_glist = []

for line in top_genres:
    line.strip(" ")
    top_glist.append(line.split("\t"))
    
#columns_df = ['Genre', 'Count']
genres_df = pd.DataFrame(data = top_glist, columns =['Genre', 'Count'] )

# %% [markdown]
# ## Display top 15 genres by count

# %%
genres_df['Count'] = pd.to_numeric(genres_df['Count'])
genres_df.nlargest(15, 'Count')
# Out:
#                        Genre   Count
# 139                    tango  1066.0
# 160            vintage tango  1066.0
# 138                    swing   389.0
# 103         new orleans jazz   342.0
# 33                 classical   308.0
# 70        harlem renaissance   297.0
# 1            adult standards   289.0
# 136                   stride   282.0
# 50                 dixieland   276.0
# 37     classical performance   266.0
# 163               vocal jazz   260.0
# 38           classical piano   236.0
# 14                  big band   230.0
# 124  russian classical piano   209.0
# 143            tin pan alley   199.0
