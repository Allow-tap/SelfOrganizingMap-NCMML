# %% [markdown]
# ## Feature Extraction using Correlation Matrix with genre as target

# %%
import ast
import pandas as pd
import seaborn as sn
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
# %matplotlib inline

from minisom import MiniSom
from sklearn.preprocessing import minmax_scale, scale

# %%
data = pd.read_csv('../data_local/tracks_with_genres.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 531191 entries, 0 to 531190
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        531191 non-null  int64
#  1   id                531191 non-null  object
#  2   name              531191 non-null  object
#  3   popularity        531191 non-null  int64
#  4   duration_ms       531191 non-null  int64
#  5   explicit          531191 non-null  int64
#  6   artists           531191 non-null  object
#  7   id_artists        531191 non-null  object
#  8   release_date      531191 non-null  object
#  9   danceability      531191 non-null  float64
#  10  energy            531191 non-null  float64
#  11  key               531191 non-null  int64
#  12  loudness          531191 non-null  float64
#  13  mode              531191 non-null  int64
#  14  speechiness       531191 non-null  float64
#  15  acousticness      531191 non-null  float64
#  16  instrumentalness  531191 non-null  float64
#  17  liveness          531191 non-null  float64
#  18  valence           531191 non-null  float64
#  19  tempo             531191 non-null  float64
#  20  time_signature    531191 non-null  int64
#  21  genres            531191 non-null  object
# dtypes: float64(9), int64(7), object(6)
# memory usage: 89.2+ MB

# %%
# Convert columns containing lists to actual Python lists
data['genres'] = data['genres'].apply(ast.literal_eval)

# %%
explode_genres = data.explode('genres').dropna()
#artists_to_genres.columns = ['artist_id', 'genre']
explode_genres.head()
# Out:
#    Unnamed: 0                      id                                name  \
# 0           0  07A5yehtSnoedViJAZkNnc  Vivo para Quererte - Remasterizado
# 0           0  07A5yehtSnoedViJAZkNnc  Vivo para Quererte - Remasterizado
# 1           1  08FmqUhxtyLTn6pAh6bk45       El Prisionero - Remasterizado
# 1           1  08FmqUhxtyLTn6pAh6bk45       El Prisionero - Remasterizado
# 2           2  08y9GfoqCWfOGsKdwojr5e                 Lady of the Evening
#
#    popularity  duration_ms  explicit              artists  \
# 0           0       181640         0  ['Ignacio Corsini']
# 0           0       181640         0  ['Ignacio Corsini']
# 1           0       176907         0  ['Ignacio Corsini']
# 1           0       176907         0  ['Ignacio Corsini']
# 2           0       163080         0      ['Dick Haymes']
#
#                    id_artists release_date  danceability  ...  loudness  mode  \
# 0  ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21         0.434  ...   -21.180     1
# 0  ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21         0.434  ...   -21.180     1
# 1  ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21         0.321  ...   -27.961     1
# 1  ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21         0.321  ...   -27.961     1
# 2  ['3BiJGZsyX9sJchTqcSA7Su']         1922         0.402  ...   -16.900     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0512         0.994            0.0218     0.212    0.457  130.418
# 0       0.0512         0.994            0.0218     0.212    0.457  130.418
# 1       0.0504         0.995            0.9180     0.104    0.397  169.980
# 1       0.0504         0.995            0.9180     0.104    0.397  169.980
# 2       0.0390         0.989            0.1300     0.311    0.196  103.220
#
#    time_signature           genres
# 0               5            tango
# 0               5    vintage tango
# 1               3            tango
# 1               3    vintage tango
# 2               4  adult standards
#
# [5 rows x 22 columns]

# %%
keylist = ['rock',
 'filmi',
 'adult standards',
 'classical',
 'classic rock',
 'mellow gold',
 'classical performance',
 'latin',
 'soft rock',
 'album rock',
 'sufi',
 'folk rock',
 'vocal jazz',
 'classic bollywood',
 'desi pop']

# %%
#data[data.isin('')]
explode_genres_1 = explode_genres['genres'].isin(keylist)
explode_genres[explode_genres_1]
# Out:
#         Unnamed: 0                      id  \
# 2                2  08y9GfoqCWfOGsKdwojr5e
# 3                3  0BRXJHRNGQ3W4v9frnSfhu
# 14              14  1HXdv1z9RlvrcUernyf0MY
# 17              17  1MD0Obbza9l0t0Zpgcwagy
# 18              18  1O9iZyzufN1fUdVO97mmm5
# ...            ...                     ...
# 531026      531026  2NxIIb2OZ1DSbfWAH0W47B
# 531029      531029  4q71x7UmINGOmompqc6IkC
# 531079      531079  1p8Po4X9rWvMOuGR2vhVI2
# 531079      531079  1p8Po4X9rWvMOuGR2vhVI2
# 531091      531091  3zLTPuucd3e6TxZnu2dlVS
#
#                                                     name  popularity  \
# 2                                    Lady of the Evening           0
# 3                                              Ave Maria           0
# 14                              The Dear Little Shamrock           0
# 17                                              And Mimi           0
# 18                                     How High the Moon           0
# ...                                                  ...         ...
# 531026                Cough Syrup - Alternate Radio Edit          39
# 531029  Boomerang (feat. Akon, Pitbull & Jermaine Dupri)          43
# 531079                            Canon in D Major, P.37          59
# 531079                            Canon in D Major, P.37          59
# 531091   Bagatelle No. 25 in A Minor, WoO 59 "Für Elise"          48
#
#         duration_ms  explicit  \
# 2            163080         0
# 3            178933         0
# 14           191613         0
# 17           186147         0
# 18           175333         0
# ...             ...       ...
# 531026       234346         0
# 531029       209636         1
# 531079       288853         0
# 531079       288853         0
# 531091       212067         0
#
#                                                   artists  \
# 2                                         ['Dick Haymes']
# 3                                         ['Dick Haymes']
# 14                                        ['Dick Haymes']
# 17      ['Dick Haymes', 'Gordon Jenkins', 'His Orchest...
# 18        ['Dick Haymes', 'Harry James', 'His Orchestra']
# ...                                                   ...
# 531026                                ['Young the Giant']
# 531029  ['DJ Felli Fel', 'Akon', 'Jermaine Dupri', 'Pi...
# 531079  ['Johann Pachelbel', 'Music Lab Collective', '...
# 531079  ['Johann Pachelbel', 'Music Lab Collective', '...
# 531091             ['Ludwig van Beethoven', 'Igor Levit']
#
#                                                id_artists release_date  \
# 2                              ['3BiJGZsyX9sJchTqcSA7Su']         1922
# 3                              ['3BiJGZsyX9sJchTqcSA7Su']         1922
# 14                             ['3BiJGZsyX9sJchTqcSA7Su']         1922
# 17      ['3BiJGZsyX9sJchTqcSA7Su', '58wzyK6DupVsypvs3Q...         1922
# 18      ['3BiJGZsyX9sJchTqcSA7Su', '5MpELOfAiq7aIBTij3...         1922
# ...                                                   ...          ...
# 531026                         ['4j56EQDQu5XnL7R3E9iFJT']   2011-08-19
# 531029  ['7sHWvTWufU865WrWckjyE0', '0z4gvV4rjIZ9wHck67...   2011-03-27
# 531079  ['62TD7509VQIxUe4WpwO0s3', '1ylcY77FWeSVQKh5et...   2015-03-01
# 531079  ['62TD7509VQIxUe4WpwO0s3', '1ylcY77FWeSVQKh5et...   2015-03-01
# 531091  ['2wOqMjp9TyABvtHdOSOTUS', '0japPUWMmW3gxqjSB1...         2015
#
#         danceability  ...  loudness  mode  speechiness  acousticness  \
# 2              0.402  ...   -16.900     0       0.0390        0.9890
# 3              0.227  ...   -12.343     1       0.0382        0.9940
# 14             0.347  ...   -15.652     1       0.0504        0.9910
# 17             0.284  ...   -15.733     0       0.0453        0.9800
# 18             0.328  ...   -11.573     1       0.0484        0.9890
# ...              ...  ...       ...   ...          ...           ...
# 531026         0.537  ...    -7.243     0       0.0449        0.0158
# 531029         0.826  ...    -5.854     0       0.0636        0.0665
# 531079         0.407  ...   -17.925     1       0.0427        0.9880
# 531079         0.407  ...   -17.925     1       0.0427        0.9880
# 531091         0.289  ...   -30.790     0       0.0446        0.9870
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 2               0.130000    0.3110   0.1960  103.220               4
# 3               0.247000    0.0977   0.0539  118.891               4
# 14              0.000133    0.1960   0.2460  109.338               3
# 17              0.081300    0.3450   0.2260   77.234               3
# 18              0.277000    0.2100   0.2590  117.225               4
# ...                  ...       ...      ...      ...             ...
# 531026          0.000171    0.1050   0.2370  128.962               3
# 531029          0.000000    0.1430   0.7570  127.047               4
# 531079          0.942000    0.1130   0.2160  105.484               4
# 531079          0.942000    0.1130   0.2160  105.484               4
# 531091          0.911000    0.1020   0.1180  125.610               3
#
#                        genres
# 2             adult standards
# 3             adult standards
# 14            adult standards
# 17            adult standards
# 18            adult standards
# ...                       ...
# 531026                   rock
# 531029                  latin
# 531079              classical
# 531079  classical performance
# 531091              classical
#
# [307056 rows x 22 columns]

# %%
rock = explode_genres[explode_genres.genres == "rock"]
rock
# Out:
#         Unnamed: 0                      id  \
# 21317        21317  5q81BdrwQhYFScqkmEMh1n
# 21460        21460  75iLtFtHmL3kBFSspqdLRC
# 21955        21955  3RYwxAkUbHCzCmX8M0C0Zd
# 22046        22046  2KIz4ileT7mvzFhAR8U5gS
# 22061        22061  6RpRXXv69SeNcRqScvyd0F
# ...            ...                     ...
# 530674      530674  5UsYQnUKMAowBi8ML0A4GK
# 530718      530718  2oop1QRqzF3v8nUjGFY7qW
# 530745      530745  5oYVxPifOLi4PccQyeYlJS
# 530779      530779  4By9LAIYRNTE87iOCqCy4y
# 531026      531026  2NxIIb2OZ1DSbfWAH0W47B
#
#                                           name  popularity  duration_ms  \
# 21317                               Ooby Dooby          24       130500
# 21460                                 Go Go Go          21       126500
# 21955     School Day (Ring Ring Goes The Bell)          52       160693
# 22046                  Brown Eyed Handsome Man          40       137107
# 22061                            No Money Down          39       177200
# ...                                        ...         ...          ...
# 530674                           Song For Love          31       355573
# 530718                            All For Love          27       287493
# 530745  Galapagos - Instrumental/Sadlands Demo          34       234440
# 530779                        Gates of Babylon          27       432065
# 531026      Cough Syrup - Alternate Radio Edit          39       234346
#
#         explicit                                  artists  \
# 21317          0                          ['Roy Orbison']
# 21460          0                          ['Roy Orbison']
# 21955          0                          ['Chuck Berry']
# 22046          0                          ['Chuck Berry']
# 22061          0                          ['Chuck Berry']
# ...          ...                                      ...
# 530674         0                              ['Extreme']
# 530718         0  ['Rod Stewart', 'Bryan Adams', 'Sting']
# 530745         0                ['The Smashing Pumpkins']
# 530779         0                     ['Yngwie Malmsteen']
# 531026         0                      ['Young the Giant']
#
#                                                id_artists release_date  \
# 21317                          ['0JDkhL4rjiPNEp92jAgJnS']   1956-01-01
# 21460                          ['0JDkhL4rjiPNEp92jAgJnS']   1956-01-01
# 21955                          ['293zczrfYafIItmnmM3coR']   1957-05-01
# 22046                          ['293zczrfYafIItmnmM3coR']   1957-05-01
# 22061                          ['293zczrfYafIItmnmM3coR']   1957-05-01
# ...                                                   ...          ...
# 530674                         ['6w7j5wQ5AI5OQYlcM15s2L']   1990-01-01
# 530718  ['2y8Jo9CKhJvtfeKOsYzRdT', '3Z02hBLubJxuFJfhac...   1993-12-13
# 530745                         ['40Yq4vzPs9VNUrIBG5Jr2i']         1995
# 530779                         ['5DpSoH5zCXNRqYai7pmcGG']   1996-10-14
# 531026                         ['4j56EQDQu5XnL7R3E9iFJT']   2011-08-19
#
#         danceability  ...  loudness  mode  speechiness  acousticness  \
# 21317          0.510  ...    -8.226     1       0.0693       0.57700
# 21460          0.594  ...    -6.138     0       0.0454       0.05990
# 21955          0.773  ...    -5.157     1       0.0438       0.82100
# 22046          0.515  ...    -7.085     1       0.2020       0.91900
# 22061          0.795  ...    -6.063     1       0.1830       0.90100
# ...              ...  ...       ...   ...          ...           ...
# 530674         0.266  ...    -7.856     1       0.0370       0.01820
# 530718         0.460  ...    -8.011     1       0.0291       0.17400
# 530745         0.413  ...   -11.946     1       0.0342       0.98300
# 530779         0.221  ...    -7.421     1       0.0565       0.00138
# 531026         0.537  ...    -7.243     0       0.0449       0.01580
#
#         instrumentalness  liveness  valence    tempo  time_signature  genres
# 21317           0.022300    0.0560   0.9400  181.225               4    rock
# 21460           0.000047    0.1770   0.4040  109.344               4    rock
# 21955           0.000016    0.1090   0.9470  130.948               4    rock
# 22046           0.000006    0.1700   0.8730  180.070               4    rock
# 22061           0.000036    0.3280   0.8490   97.444               4    rock
# ...                  ...       ...      ...      ...             ...     ...
# 530674          0.000005    0.3330   0.3740  144.831               4    rock
# 530718          0.000000    0.3590   0.1270  149.938               4    rock
# 530745          0.946000    0.0988   0.0679  118.348               4    rock
# 530779          0.232000    0.2650   0.2710  125.448               4    rock
# 531026          0.000171    0.1050   0.2370  128.962               3    rock
#
# [32208 rows x 22 columns]

# %% [markdown]
# ## Select columns for feature selection

# %%
rock['genres'] = 1
feature_select = ['genres','speechiness', 'valence', 'tempo', 'danceability']

X = rock[feature_select].values
X = scale(X)

#genres = np.random.normal(0, 1, X.shape[0])
#genres = np.random.normal(0, 1, X.shape[0])
#X[:,0] = 1

feature_df = pd.DataFrame(X, columns=feature_select)
# Out:
# <ipython-input-24-a3f05fdd91ad>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rock['genres'] = 1

# %%
feat_num = len(feature_df)

# plt.figure(figsize=(feat_num,feat_num/2))
corrMatrix = feature_df.corr().round(2)
sn.heatmap(corrMatrix, annot=True)

# plt.tight_layout()
    
plt.show()

# %%
rock.info()
